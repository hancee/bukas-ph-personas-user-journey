# %%
#Standard and visualization libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from jupyterthemes import jtplot
# %matplotlib inline
jtplot.style(theme='oceans16')

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Bukas - FTW Raw Data -Copy1.xlsx')
df.head()
# Out:
#   applicant_id  borrower_city_id borrower_date_of_birth  borrower_province_id  \
# 0        A0001               NaN                    NaT                   NaN
# 1        A0002               NaN                    NaT                   NaN
# 2        A0003          137603.0             1999-09-21                  72.0
# 3        A0004          133901.0             1984-04-14                  68.0
# 4        A0005               NaN                    NaT                   NaN
#
#   borrower_school_billing_file borrower_school_enrollment_file  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
#
#    borrower_zip_code date_needed               datetime_created  \
# ...

# %%
melted = pd.melt(df, id_vars=['applicant_id'], value_vars= ['education_course','education_dorm_address',
                 'previous_principal','date_needed','borrower_date_of_birth','borrower_province_id',
                             'borrower_city_id','borrower_zip_code','education_school_id'], var_name=["step"] , value_name="conversion")

melted
# Out:
#       applicant_id                 step  \
# 0            A0001     education_course
# 1            A0002     education_course
# 2            A0003     education_course
# 3            A0004     education_course
# 4            A0005     education_course
# 5            A0006     education_course
# 6            A0007     education_course
# 7            A0008     education_course
# 8            A0009     education_course
# 9            A0010     education_course
# 10           A0011     education_course
# 11           A0012     education_course
# 12           A0013     education_course
# 13           A0014     education_course
# 14           A0015     education_course
# 15           A0016     education_course
# 16           A0017     education_course
# 17           A0018     education_course
# 18           A0019     education_course
# 19           A0020     education_course
# 20           A0021     education_course
# 21           A0022     education_course
# ...

# %%
response = melted['conversion'].notnull()
response
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
# 5         True
# 6        False
# 7        False
# 8        False
# 9        False
# 10        True
# 11       False
# 12       False
# 13        True
# 14       False
# 15       False
# 16        True
# 17       False
# 18        True
# 19       False
# 20       False
# 21        True
# 22        True
# 23        True
# 24       False
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 20427     True
# 20428     True
# 20429     True
# 20430    False
# 20431     True
# 20432    False
# 20433     True
# 20434     True
# 20435     True
# 20436     True
# 20437     True
# 20438     True
# 20439     True
# 20440     True
# 20441     True
# 20442     True
# 20443     True
# 20444     True
# 20445     True
# 20446     True
# 20447     True
# 20448     True
# 20449     True
# 20450     True
# 20451     True
# 20452     True
# 20453     True
# ...

# %%
melted['response'] = response
melted
# Out:
#       applicant_id                 step  \
# 0            A0001     education_course
# 1            A0002     education_course
# 2            A0003     education_course
# 3            A0004     education_course
# 4            A0005     education_course
# 5            A0006     education_course
# 6            A0007     education_course
# 7            A0008     education_course
# 8            A0009     education_course
# 9            A0010     education_course
# 10           A0011     education_course
# 11           A0012     education_course
# 12           A0013     education_course
# 13           A0014     education_course
# 14           A0015     education_course
# 15           A0016     education_course
# 16           A0017     education_course
# 17           A0018     education_course
# 18           A0019     education_course
# 19           A0020     education_course
# 20           A0021     education_course
# 21           A0022     education_course
# ...
